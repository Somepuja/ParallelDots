# %%
import glob as glob_lib
import os
from utils import *
import numpy as np
from PIL import Image
from pycocotools import mask as maskUtils

# %% [markdown]
# ## code starts here

# %%
CATEGORIES = {
    "can_chowder": {
        "ref_img": 'data/data_2D/can_chowder_000001.jpg',
        "ref_mask": 'data/data_2D/can_chowder_000001_1_gt.png',
    },
    "can_soymilk": {
        "ref_img": 'data/data_2D/can_soymilk_000001.jpg',
        "ref_mask": 'data/data_2D/can_soymilk_000001_1_gt.png',
    },
    "can_tomatosoup": {
        "ref_img": 'data/data_2D/can_tomatosoup_000001.jpg',
        "ref_mask": 'data/data_2D/can_tomatosoup_000001_1_gt.png',
    },
    "carton_oj": {
        "ref_img": 'data/data_2D/carton_oj_000001.jpg',
        "ref_mask": 'data/data_2D/carton_oj_000001_1_gt.png',
    },
    "carton_soymilk": {
        "ref_img": 'data/data_2D/carton_soymilk_000001.jpg',
        "ref_mask": 'data/data_2D/carton_soymilk_000001_1_gt.png',
    },
    "diet_coke": {
        "ref_img": 'data/data_2D/diet_coke_000001.jpg',
        "ref_mask": 'data/data_2D/diet_coke_000001_1_gt.png',
    },
    "hc_potroastsoup": {
        "ref_img": 'data/data_2D/hc_potroastsoup_000001.jpg',
        "ref_mask": 'data/data_2D/hc_potroastsoup_000001_1_gt.png',
    },
    "juicebox": {
        "ref_img": 'data/data_2D/juicebox_000001.jpg',
        "ref_mask": 'data/data_2D/juicebox_000001_1_gt.png',
    },
    "rice_tuscan": {
        "ref_img": 'data/data_2D/rice_tuscan_000001.jpg',
        "ref_mask": 'data/data_2D/rice_tuscan_000001_1_gt.png',
    },
    "ricepilaf": {
        "ref_img": 'data/data_2D/ricepilaf_000001.jpg',
        "ref_mask": 'data/data_2D/ricepilaf_000001_1_gt.png',
    },
}

# %%
IMG_EXTS = (".jpg", ".jpeg", ".png")

def build_categories_with_tests(categories):
    """
    Given initial dict with ref_img/ref_mask, fill in test = [[test_img, test_mask], ...]
    categories: {
        "cat_key": {
            "ref_img": <path>,
            "ref_mask": <path>
        }, ...
    }
    """
    for cat, data in categories.items():
        ref_img = data["ref_img"]
        ref_mask = data["ref_mask"]

        folder = os.path.dirname(ref_img)
        prefix = "_".join(os.path.basename(ref_img).split("_")[:-1])  # e.g., can_chowder

        # Find all candidate images (exclude ref and masks)
        all_imgs = []
        for ext in IMG_EXTS:
            all_imgs.extend(glob.glob(os.path.join(folder, f"{prefix}_*{ext}")))
        test_imgs = [
            p for p in all_imgs
            if "_gt" not in os.path.basename(p).lower()
            and os.path.abspath(p) != os.path.abspath(ref_img)
        ]
        test_imgs = sorted(test_imgs)

        test_pairs = []
        for img_path in test_imgs:
            base_name = os.path.splitext(os.path.basename(img_path))[0]
            mask_path = None

            # Try *_1_gt first
            for ext in IMG_EXTS:
                candidate = os.path.join(folder, f"{base_name}_1_gt{ext}")
                if os.path.exists(candidate):
                    mask_path = candidate
                    break

            # If not found, try any *_gt
            if mask_path is None:
                for ext in IMG_EXTS:
                    matches = glob.glob(os.path.join(folder, f"{base_name}_*_gt{ext}"))
                    if matches:
                        mask_path = sorted(matches)[0]
                        break

            if not mask_path:
                raise FileNotFoundError(f"No mask found for test image {img_path}")

            test_pairs.append([img_path, mask_path])

        data["test"] = test_pairs

    return categories

# %%
def process_categories(categories_dict, visualize=False):
    """
    Loops through each category and its test pairs.
    Returns:
    {
      category_key: [
        {
          "ref_img": <ref image path>,
          "ref_mask": <ref mask path>,
          "test_img": <test image path>,
          "test_mask": <test mask path>,
          "relevant_mask": <predicted mask array>
        },
        ...
      ]
    }
    """
    results = {}

    for category_key, cfg in categories_dict.items():
        ref_img  = cfg["ref_img"]
        ref_mask = cfg["ref_mask"]

        # Get bounding box from reference
        xmin, xmax, ymin, ymax = process_img_png_mask(
            ref_img, ref_mask, visualize=visualize
        )

        cat_results = []
        for pair in cfg.get("test", []):
            if not isinstance(pair, (list, tuple)) or len(pair) != 2:
                continue

            test_img, test_mask = pair

            if os.path.abspath(test_img) == os.path.abspath(ref_img):
                continue

            # Run tracker
            op = track_item_boxes(
                ref_img,
                test_img,
                [([xmin, xmax, ymin, ymax], 1)],
                visualize=visualize
            )
            output_masks = op[1]
            relevant_mask = output_masks[1]

            cat_results.append({
                "ref_img": ref_img,
                "ref_mask": ref_mask,
                "test_img": test_img,
                "test_mask": test_mask,
                "relevant_mask": relevant_mask
            })

        results[category_key] = cat_results

    return results

# %%
def _normalize_mask(mask, target_shape=None):
    m = np.asarray(mask)

    # remove singleton dims like (1,H,W) or (H,W,1)
    m = np.squeeze(m)
    if m.ndim == 3 and m.shape[2] == 1:
        m = m[:, :, 0]
    if m.ndim == 3 and m.shape[0] == 1:
        m = m[0]

    # binarize (works for bool, uint8 0/1, or float logits/probs)
    if m.dtype != bool:
        if m.dtype.kind in ("f", "c"):
            m = m > 0.5
        else:
            m = m > 0

    # resize if requested and shapes differ (nearest to preserve labels)
    if target_shape and m.shape != target_shape:
        im = Image.fromarray(m.astype(np.uint8) * 255)
        im = im.resize((target_shape[1], target_shape[0]), Image.NEAREST)
        m = np.array(im) > 0

    return m.astype(np.uint8)  # pycocotools likes 0/1 uint8

def eval_masks_with_coco(gt_mask_path, pred_mask, auto_resize=True):
    # 1) GT mask from image path -> boolean
    gt = Image.open(gt_mask_path).convert("L")
    gt = np.array(gt) > 0

    # 2) normalize predicted mask to (H,W) bool, align shape
    pred = _normalize_mask(pred_mask, target_shape=gt.shape if auto_resize else None)

    # sanity check
    if gt.shape != pred.shape:
        raise ValueError(f"Shape mismatch after normalization: GT {gt.shape}, Pred {pred.shape}")

    # 3) RLE encode (Fortran order)
    gt_rle   = maskUtils.encode(np.asfortranarray(gt.astype(np.uint8)))
    pred_rle = maskUtils.encode(np.asfortranarray(pred.astype(np.uint8)))

    # 4) areas
    gt_area   = float(maskUtils.area(gt_rle))
    pred_area = float(maskUtils.area(pred_rle))

    # 5) IoU (iscrowd=0)
    iou = float(maskUtils.iou([pred_rle], [gt_rle], [0])[0][0])

    return {"gt_area_px": gt_area, "pred_area_px": pred_area, "iou": iou}

# %%
# Build categories with ref and test 
CATEGORIES = build_categories_with_tests(CATEGORIES)

# create mask and closebox for test image 
results = process_categories(CATEGORIES)
# Out:
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.36it/s]
# /home/anjali/sam2/sam2/sam2_video_predictor.py:786: UserWarning: cannot import name '_C' from 'sam2' (/home/anjali/sam2/sam2/__init__.py)
#
# Skipping the post-processing step due to the error above. You can still use SAM 2 and it's OK to ignore the error above, although some post-processing functionality may be limited (which doesn't affect the results in most cases; see https://github.com/facebookresearch/sam2/blob/main/INSTALL.md).
#   pred_masks_gpu = fill_holes_in_mask_scores(
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 24.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 25.24it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 67.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 26.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.09it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 24.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 65.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 24.72it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 25.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 24.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.81it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 24.20it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 23.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 65.31it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 24.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.09it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 25.20it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 24.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.38it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.49it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 64.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.82it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.36it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.91it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.82it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.16it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.80it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 23.91it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 22.72it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.82it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.96it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 65.30it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 22.95it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.19it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 23.33it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.87it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.73it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 22.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 22.56it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.97it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.20it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.16it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 25.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.37it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 22.56it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.37it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.78it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.78it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 65.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.69it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.36it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.84it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.14it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.73it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.92it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.37it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.37it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.60it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.73it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.84it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.23it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.81it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 40.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.49it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.56it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.07it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.16it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.47it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.72it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.65it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.30it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.96it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.34it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.75it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.84it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.14it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.16it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.36it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.38it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.78it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.56it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.38it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.79it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.47it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.69it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.25it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.81it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.34it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.85it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.40it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.53it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 39.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.21it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.56it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.97it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.14it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.70it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.23it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.16it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 37.53it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 41.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.40it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.38it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.70it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.78it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.36it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.36it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.57it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.93it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 65.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.34it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.57it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.31it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.30it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.20it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.05it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.32it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.97it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.79it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.38it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.17it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.12it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.76it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.79it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.34it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.21it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.07it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.65it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.31it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.36it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.98it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.95it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 36.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.53it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.38it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.08it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.57it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.47it/s]
# propagate in video: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.79it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 64.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.16it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.66it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.78it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.65it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.40it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.57it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.05it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.31it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.57it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.24it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.73it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.80it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.05it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.03it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.73it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.91it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.47it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.87it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.95it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.47it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.53it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.65it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.71it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.43it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.37it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 64.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.47it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.70it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.37it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.08it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.91it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.17it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.32it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.53it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.36it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.09it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.98it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.07it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.29it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.53it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.60it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.38it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.25it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.84it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.75it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.14it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.24it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.70it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.32it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.05it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.45it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.89it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.21it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.95it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.72it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.24it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.33it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.87it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.49it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.09it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.95it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.36it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.53it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.49it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.57it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.23it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.72it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.14it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.93it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.29it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.67it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.23it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.59it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.40it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.60it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.49it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.95it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.16it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.40it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.40it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 43.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.94it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.16it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:02<00:00,  1.35s/it]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.38it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.68it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.84it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 43.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.65it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.89it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.81it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.37it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.08it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.89it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.69it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 44.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.82it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.53it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.49it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.79it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.40it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.57it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.57it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.72it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.38it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.71it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 43.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.37it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 10.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.59it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.87it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.78it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 42.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 44.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.56it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.71it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.81it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.47it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.08it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.45it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.98it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.22it/s]
# ...
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.07it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 44.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.80it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.38it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.68it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.79it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.89it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.07it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.72it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.71it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.92it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.78it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.97it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.91it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.71it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.37it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.05it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.17it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.08it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.89it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.47it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.81it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.56it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.14it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.70it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.95it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.94it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.82it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.97it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.80it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.49it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.18it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.25it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.16it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.29it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.14it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.36it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.38it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.47it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.76it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.78it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.72it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.70it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.92it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.40it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.31it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.08it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.82it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.72it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.71it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.78it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.59it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.40it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.53it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.67it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.70it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.72it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.47it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.96it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.84it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.59it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.68it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.94it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.03it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.37it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.68it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.84it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.21it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.78it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.71it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.85it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.17it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.78it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.40it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.71it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.57it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.08it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.57it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 11.97it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.75it/s]

# %%
results
# Out:
# {'can_chowder': [{'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000002.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000002_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000003.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000003_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000004.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000004_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000005.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000005_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000006.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000006_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000007.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000007_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000008.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000008_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000009.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000009_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000010.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000010_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000011.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000011_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000012.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000012_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000013.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000013_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000014.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000014_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000015.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000015_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000016.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000016_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000017.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000017_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000018.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000018_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000019.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000019_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000020.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000020_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000021.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000021_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000022.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000022_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000023.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000023_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000024.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000024_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000025.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000025_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000026.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000026_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000027.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000027_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000028.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000028_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000029.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000029_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000030.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000030_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000031.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000031_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000032.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000032_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000033.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000033_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000034.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000034_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000035.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000035_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000036.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000036_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000037.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000037_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000038.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000038_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000039.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000039_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000040.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000040_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000041.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000041_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000042.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000042_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000043.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000043_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000044.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000044_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000045.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000045_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000046.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000046_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000047.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000047_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000048.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000048_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000049.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000049_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_chowder_000001.jpg',
#    'ref_mask': 'data/data_2D/can_chowder_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_chowder_000050.jpg',
#    'test_mask': 'data/data_2D/can_chowder_000050_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])}],
#  'can_soymilk': [{'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000002.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000002_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000003.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000003_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000004.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000004_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000005.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000005_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000006.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000006_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000007.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000007_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000008.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000008_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000009.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000009_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000010.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000010_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000011.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000011_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000012.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000012_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000013.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000013_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000014.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000014_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000015.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000015_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000016.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000016_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000017.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000017_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000018.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000018_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000019.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000019_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000020.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000020_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000021.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000021_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000022.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000022_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000023.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000023_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000024.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000024_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000025.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000025_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000026.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000026_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000027.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000027_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000028.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000028_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/can_soymilk_000001.jpg',
#    'ref_mask': 'data/data_2D/can_soymilk_000001_1_gt.png',
#    'test_img': 'data/data_2D/can_soymilk_000029.jpg',
#    'test_mask': 'data/data_2D/can_soymilk_000029_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
# ...
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000025.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000025_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000026.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000026_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000027.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000027_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000028.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000028_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000029.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000029_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000030.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000030_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000031.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000031_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000032.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000032_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000033.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000033_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000034.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000034_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000035.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000035_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000036.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000036_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000037.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000037_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000038.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000038_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000039.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000039_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000040.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000040_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000041.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000041_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000042.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000042_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000043.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000043_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000044.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000044_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000045.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000045_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000046.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000046_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000047.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000047_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000048.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000048_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000049.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000049_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])},
#   {'ref_img': 'data/data_2D/ricepilaf_000001.jpg',
#    'ref_mask': 'data/data_2D/ricepilaf_000001_1_gt.png',
#    'test_img': 'data/data_2D/ricepilaf_000050.jpg',
#    'test_mask': 'data/data_2D/ricepilaf_000050_1_gt.png',
#    'relevant_mask': array([[[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]])}]}

# %%
metrics = eval_masks_with_coco(results['can_chowder'][6]['test_mask'], results['can_chowder'][6]['relevant_mask'], auto_resize=False)
print(metrics)
# Out:
# {'gt_area_px': 9210.0, 'pred_area_px': 11121.0, 'iou': 0.6851222544550353}

# %%
# # pip install pycocotools   # on Windows you may need: pip install pycocotools-windows
# import numpy as np
# from pycocotools import mask as maskUtils
# from math import floor, ceil

# def bbox_to_rle(bbox, H=None, W=None):
#     """
#     bbox: [x, y, w, h] (floats ok)
#     H, W: image height/width; if None, use the minimum canvas that fits both boxes later
#     returns: RLE dict
#     """
#     x, y, w, h = bbox
#     x0, y0 = floor(x), floor(y)
#     x1, y1 = ceil(x + w), ceil(y + h)

#     if H is None or W is None:
#         H = max(H or 0, y1 + 1)
#         W = max(W or 0, x1 + 1)

#     mask = np.zeros((H, W), dtype=np.uint8)
#     # clip to canvas just in case
#     x0c, y0c = max(0, x0), max(0, y0)
#     x1c, y1c = min(W, x1), min(H, y1)
#     if x1c > x0c and y1c > y0c:
#         mask[y0c:y1c, x0c:x1c] = 1

#     rle = maskUtils.encode(np.asfortranarray(mask))
#     return rle, (H, W)

# def iou_from_boxes(gt_bbox, pred_bbox):
#     # build a canvas big enough for both
#     def box_extent(b):
#         x, y, w, h = b
#         return ceil(x + w), ceil(y + h)
#     W = max(box_extent(gt_bbox)[0], box_extent(pred_bbox)[0]) + 1
#     H = max(box_extent(gt_bbox)[1], box_extent(pred_bbox)[1]) + 1

#     gt_rle, _   = bbox_to_rle(gt_bbox, H=H, W=W)
#     pred_rle, _ = bbox_to_rle(pred_bbox, H=H, W=W)

#     # areas
#     gt_area   = float(maskUtils.area(gt_rle))
#     pred_area = float(maskUtils.area(pred_rle))

#     # IoU (mask-based)
#     # maskUtils.iou expects lists of RLEs and a matching iscrowd list
#     iou = maskUtils.iou([pred_rle], [gt_rle], [0])[0][0]

#     return {
#         "gt_area_px": gt_area,
#         "pred_area_px": pred_area,
#         "iou": float(iou),
#         "canvas_HW": (H, W),
#     }

# %%
# # ---- Your rectangles ----
# gt = results['can_chowder'][8]['bbox_test_mask_xywh']  # actual
# pd = results['can_chowder'][8]['bbox_relevant_mask_xywh']  # predicted

# metrics = iou_from_boxes(gt, pd)
# print(metrics)
# Out:
# {'gt_area_px': 13184.0, 'pred_area_px': 12096.0, 'iou': 0.9174757281553398, 'canvas_HW': (194, 577)}
