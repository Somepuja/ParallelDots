# %%
import glob as glob_lib
import os
from utils import *
import numpy as np
from PIL import Image
from pycocotools import mask as maskUtils
import pandas as pd

# %% [markdown]
# ## 1. Defining Dataset Categories and Reference Files
#
# We set up a structured mapping of all the product categories we will process.
# The `CATEGORIES` dictionary links each product to:
# - **`ref_img`**: A reference image for the product.
# - **`ref_mask`**: The corresponding ground-truth segmentation mask.
#
# For example:
# - `"can_chowder"` → Image: `data/data_2D/can_chowder_000001.jpg`, Mask: `data/data_2D/can_chowder_000001_1_gt.png`

# %%
CATEGORIES = {
    "can_chowder": {
        "ref_img": 'data/data_2D/can_chowder_000001.jpg',
        "ref_mask": 'data/data_2D/can_chowder_000001_1_gt.png',
    },
    "can_soymilk": {
        "ref_img": 'data/data_2D/can_soymilk_000001.jpg',
        "ref_mask": 'data/data_2D/can_soymilk_000001_1_gt.png',
    },
    "can_tomatosoup": {
        "ref_img": 'data/data_2D/can_tomatosoup_000001.jpg',
        "ref_mask": 'data/data_2D/can_tomatosoup_000001_1_gt.png',
    },
    "carton_oj": {
        "ref_img": 'data/data_2D/carton_oj_000001.jpg',
        "ref_mask": 'data/data_2D/carton_oj_000001_1_gt.png',
    },
    "carton_soymilk": {
        "ref_img": 'data/data_2D/carton_soymilk_000001.jpg',
        "ref_mask": 'data/data_2D/carton_soymilk_000001_1_gt.png',
    },
    "diet_coke": {
        "ref_img": 'data/data_2D/diet_coke_000001.jpg',
        "ref_mask": 'data/data_2D/diet_coke_000001_1_gt.png',
    },
    "hc_potroastsoup": {
        "ref_img": 'data/data_2D/hc_potroastsoup_000001.jpg',
        "ref_mask": 'data/data_2D/hc_potroastsoup_000001_1_gt.png',
    },
    "juicebox": {
        "ref_img": 'data/data_2D/juicebox_000001.jpg',
        "ref_mask": 'data/data_2D/juicebox_000001_1_gt.png',
    },
    "rice_tuscan": {
        "ref_img": 'data/data_2D/rice_tuscan_000001.jpg',
        "ref_mask": 'data/data_2D/rice_tuscan_000001_1_gt.png',
    },
    "ricepilaf": {
        "ref_img": 'data/data_2D/ricepilaf_000001.jpg',
        "ref_mask": 'data/data_2D/ricepilaf_000001_1_gt.png',
    },
}

# %% [markdown]
# ## 2. Auto-discovering Test Images and Masks for Each Category
#
# Building on the category map defined above, we now **programmatically discover** all test images and their corresponding ground-truth masks for every product. This removes the need to manually list test files and keeps the pipeline scalable when new images are added.
#
# ### What this cell does
# - Defines valid image extensions: `(".jpg", ".jpeg", ".png")`.
# - Implements `build_categories_with_tests(categories)` which:
#   1. **Derives the folder and filename prefix** from each category’s `ref_img` (e.g., `can_chowder_000001.jpg` → prefix `can_chowder`).
#   2. **Finds all candidate images** in the same folder that match `{prefix}_*` and filters out:
#      - the reference image itself, and
#      - any files that are masks (contain `_gt`).
#   3. **Locates each test image’s mask** using a two-stage strategy:
#      - Prefer `*_1_gt` (e.g., `can_chowder_000002_1_gt.png`) to stay consistent with common annotations.
#      - Fallback to **any** `*_gt` match if `*_1_gt` is not present.
#   4. **Attaches discovered pairs** as `data["test"] = [[test_img, test_mask], ...]` inside the original `categories` dict.
#
#
# - The **`CATEGORIES`** dictionary gave us a single `ref_img` and `ref_mask` per class. Using those anchors, this function **expands each category** by discovering all other images and their ground truths in the same directory.
#
# ### Output
# - Returns the original `categories` dict **augmented** with a `test` key for each category:
#   ```python
#   {
#     "can_chowder": {
#       "ref_img": "...",
#       "ref_mask": "...",
#       "test": [
#         [".../can_chowder_000002.jpg", ".../can_chowder_000002_1_gt.png"],
#         ...
#       ]
#     },
#     ...
#   }

# %%
IMG_EXTS = (".jpg", ".jpeg", ".png")

def build_categories_with_tests(categories):
    """
    Given initial dict with ref_img/ref_mask, fill in test = [[test_img, test_mask], ...]
    categories: {
        "cat_key": {
            "ref_img": <path>,
            "ref_mask": <path>
        }, ...
    }
    """
    for cat, data in categories.items():
        ref_img = data["ref_img"]

        folder = os.path.dirname(ref_img)
        prefix = "_".join(os.path.basename(ref_img).split("_")[:-1])
        
        # Find all candidate images (exclude ref and masks)
        all_imgs = []
        for ext in IMG_EXTS:
            all_imgs.extend(glob.glob(os.path.join(folder, f"{prefix}_*{ext}")))
        test_imgs = [
            p for p in all_imgs
            if "_gt" not in os.path.basename(p).lower()
            and os.path.abspath(p) != os.path.abspath(ref_img)
        ]
        test_imgs = sorted(test_imgs)

        test_pairs = []
        for img_path in test_imgs:
            base_name = os.path.splitext(os.path.basename(img_path))[0]
            mask_path = None

            # Try *_1_gt
            for ext in IMG_EXTS:
                candidate = os.path.join(folder, f"{base_name}_1_gt{ext}")
                if os.path.exists(candidate):
                    mask_path = candidate
                    break

            if not mask_path:
                raise FileNotFoundError(f"No mask found for test image {img_path}")

            test_pairs.append([img_path, mask_path])

        data["test"] = test_pairs

    return categories

# %% [markdown]
# ## 3. Processing All Categories: From Reference Box to Predicted Masks
#
# Having populated each category with its discovered **test image–mask pairs**, we now iterate through the dataset to **generate predicted masks** on test images using the reference object’s bounding box.
#
# ### What this cell does
# - Defines `process_categories(categories_dict, visualize=False)` which:
#   1. Loops over each category and reads the **reference image** and **reference mask**.
#   2. Calls `process_img_png_mask(ref_img, ref_mask, visualize)` to extract the **reference object’s bounding box**
#      → returns `(xmin, xmax, ymin, ymax)`.
#   3. Iterates over every **test image** discovered earlier.
#   4. Invokes `track_item_boxes(ref_img, test_img, [([xmin, xmax, ymin, ymax], 1)], visualize)` to **track/locate** the reference object in the test image and produce a **predicted mask**.
#   5. Collects a structured record per test, including `ref_img`, `ref_mask`, `test_img`, `test_mask`, and the **`relevant_mask`** (predicted).
# - Returns a dictionary keyed by category:
#   ```python
#   {
#     "can_chowder": [
#       {
#         "ref_img": "...",
#         "ref_mask": "...",
#         "test_img": "...",
#         "test_mask": "...",
#         "relevant_mask": <ndarray bool HxWx1 or HxW>
#       },
#       ...
#     ],
#     ...
#   }

# %%
def process_categories(categories_dict, visualize=False):
    """
    Loops through each category and its test pairs.
    Returns:
    {
      category_key: [
        {
          "ref_img": <ref image path>,
          "ref_mask": <ref mask path>,
          "test_img": <test image path>,
          "test_mask": <test mask path>,
          "relevant_mask": <predicted mask array>
        },
        ...
      ]
    }
    """
    results = {}

    for category_key, cfg in categories_dict.items():
        ref_img  = cfg["ref_img"]
        ref_mask = cfg["ref_mask"]

        # Get bounding box from reference
        xmin, xmax, ymin, ymax = process_img_png_mask(
            ref_img, ref_mask, visualize=visualize
        )

        cat_results = []
        for pair in cfg.get("test", []):
            test_img, test_mask = pair

            # Run tracker
            op = track_item_boxes(
                ref_img,
                test_img,
                [([xmin, xmax, ymin, ymax], 1)],
                visualize=visualize
            )
            
            output_masks = op[1]
            relevant_mask = output_masks[1]

            cat_results.append({
                "ref_img": ref_img,
                "ref_mask": ref_mask,
                "test_img": test_img,
                "test_mask": test_mask,
                "relevant_mask": relevant_mask
            })

        results[category_key] = cat_results

    return results

# %% [markdown]
# ## 4. Normalizing Masks and Computing COCO Metrics (Area & IoU)
#
# With predicted masks generated for each test image in the previous step, we now standardize mask shapes/types and compute **quantitative evaluation** using COCO utilities.
#
# ### What this cell does
# - **`_normalize_mask(mask, target_shape=None)`**
#   - Converts any incoming mask (bool, 0/1 uint8, logits/probabilities) into a **binary** `(H, W)` array.
#   - **Squeezes** singleton dimensions (e.g., `(1, H, W)`, `(H, W, 1)`).
#   - **Binarizes**:
#     - Floats/complex → threshold at `0.5`
#     - Integers → threshold at `> 0`
#   - **Optionally resizes** to a requested `target_shape` using **nearest-neighbor** (to preserve labels).
#   - Returns **uint8 (0/1)** masks, which `pycocotools` prefers for encoding.
# - **`eval_masks_with_coco(gt_mask_path, pred_mask, auto_resize=True)`**
#   1. Loads the **ground-truth** mask from path and binarizes it.
#   2. Normalizes the **predicted** mask and, if `auto_resize=True`, aligns it to the GT shape.
#   3. Encodes both masks into **COCO RLE** (using **Fortran order** as required).
#   4. Computes **areas** (in pixels) for GT and prediction via `maskUtils.area(...)`.
#   5. Computes **Intersection-over-Union (IoU)** via `maskUtils.iou(...)` with `iscrowd=0`.
#   6. Returns a compact dict: `{"gt_area_px": ..., "pred_area_px": ..., "iou": ...}`.
#
# - In **Step 4**, we produced a **predicted mask** (`relevant_mask`) for each test image.
# - This step converts those predictions into a **standard format** and evaluates them against the **ground-truth masks** discovered in **Step 3**.
# - The result provides objective metrics to compare performance **across categories and images**.
#
# ### Expected output
# A dictionary with:
# ```python
# {
#   "gt_area_px": <float>,      # Ground-truth mask area in pixels
#   "pred_area_px": <float>,    # Predicted mask area in pixels
#   "iou": <float in [0, 1]>    # Overlap quality between prediction and ground truth
# }

# %%
def _normalize_mask(mask, target_shape=None):
    m = np.asarray(mask)

    # remove singleton dims like (1,H,W) or (H,W,1)
    m = np.squeeze(m)
    if m.ndim == 3 and m.shape[2] == 1:
        m = m[:, :, 0]
    if m.ndim == 3 and m.shape[0] == 1:
        m = m[0]

    # binarize (works for bool, uint8 0/1, or float logits/probs)
    if m.dtype != bool:
        if m.dtype.kind in ("f", "c"):
            m = m > 0.5
        else:
            m = m > 0

    # resize if requested and shapes differ (nearest to preserve labels)
    if target_shape and m.shape != target_shape:
        im = Image.fromarray(m.astype(np.uint8) * 255)
        im = im.resize((target_shape[1], target_shape[0]), Image.NEAREST)
        m = np.array(im) > 0

    return m.astype(np.uint8)

def eval_masks_with_coco(gt_mask_path, pred_mask, auto_resize=True):
    # GT mask from image path -> boolean
    gt = Image.open(gt_mask_path).convert("L")
    gt = np.array(gt) > 0

    # normalize predicted mask to (H,W) bool, align shape
    pred = _normalize_mask(pred_mask, target_shape=gt.shape if auto_resize else None)

    # sanity check
    if gt.shape != pred.shape:
        raise ValueError(f"Shape mismatch after normalization: GT {gt.shape}, Pred {pred.shape}")

    # RLE encode (Fortran order)
    gt_rle   = maskUtils.encode(np.asfortranarray(gt.astype(np.uint8)))
    pred_rle = maskUtils.encode(np.asfortranarray(pred.astype(np.uint8)))

    # areas
    gt_area   = float(maskUtils.area(gt_rle))
    pred_area = float(maskUtils.area(pred_rle))

    # IoU (iscrowd=0)
    iou = float(maskUtils.iou([pred_rle], [gt_rle], [0])[0][0])

    return {"gt_area_px": gt_area, "pred_area_px": pred_area, "iou": iou}

# %% [markdown]
# ## 5. Computing Average IoU per Category
#
# After normalizing masks and computing **IoU metrics** for individual test images in the previous step, we now summarize results **per category** to get a high-level view of performance.
#
# ### What this cell does
# - **Function:** `average_iou_per_category_from_results(...)`
# - **Inputs:**
#   - `results`: The output dictionary from **Step 4** (`process_categories`) containing test mask paths and predicted masks per category.
#   - `gt_key`: Field name in each test record that points to the ground-truth mask path (default: `"test_mask"`).
#   - `pred_key`: Field name for the predicted mask array (default: `"relevant_mask"`).
#   - `auto_resize`: Passed through to `eval_masks_with_coco`; aligns shapes if they differ.
#   - `return_details`: If `True`, also returns the list of individual IoUs per category.
# - **Process:**
#   1. Iterates over each **category** and its **test items**.
#   2. For each item, calls `eval_masks_with_coco(...)` (from Step 5) to compute the IoU.
#   3. Collects IoUs into a list for that category.
#   4. Calculates the **average IoU** using `numpy.mean`.
#   5. Optionally stores the full IoU list if `return_details=True`.
# - **Output:**
#   - If `return_details=False`:
#     ```python
#     {"can_chowder": 0.82, "rice_tuscan": 0.76, ...}
#     ```
#   - If `return_details=True`:
#     ```python
#     (
#       {"can_chowder": 0.82, "rice_tuscan": 0.76, ...},
#       {"can_chowder": [0.81, 0.83, ...], "rice_tuscan": [0.75, 0.77, ...]}
#     )
#     ```

# %%
def average_iou_per_category_from_results(
    results,
    gt_key="test_mask",
    pred_key="relevant_mask",
    auto_resize=False,
    return_details=False,
):
    """
    results: {
      "catA": [
        {"test_mask": <path>, "relevant_mask": <np.bool array or 0/1>, ...},
        ...
      ],
      "catB": [...]
    }
    gt_key:   key in each item pointing to GT mask path (default: 'test_mask')
    pred_key: key in each item pointing to predicted mask array (default: 'relevant_mask')
    auto_resize: pass-through to eval_masks_with_coco (nearest-neighbor if shapes differ)
    return_details: if True, also returns per-item IoUs for each category

    Returns:
      avg_ious: {category: avg_iou_float}
      details (optional): {category: [iou1, iou2, ...]}
    """
    avg_ious = {}
    details = {} if return_details else None

    for category, items in results.items():
        ious = []
        for idx, item in enumerate(items):
            try:
                gt_path = item[gt_key]
                pred_mask = item[pred_key]
                # Call eval_masks_with_coco function
                metrics = eval_masks_with_coco(
                    gt_mask_path=gt_path,
                    pred_mask=pred_mask,
                    auto_resize=auto_resize
                )
                ious.append(float(metrics["iou"]))
            except Exception as e:
                # Skip broken entries
                print(f"[WARN] {category} item {idx}: {e}")

        avg_ious[category] = float(np.mean(ious)) if len(ious) else 0.0
        if return_details:
            details[category] = ious

    return (avg_ious, details) if return_details else avg_ious

# %%
# Auto-discovering Test Images and Masks for Each Category 
CATEGORIES = build_categories_with_tests(CATEGORIES)

# Processing All Categories: From Reference Box to Predicted Masks 
results = process_categories(CATEGORIES)
# Out:
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.89it/s]
# /home/anjali/sam2/sam2/sam2_video_predictor.py:786: UserWarning: cannot import name '_C' from 'sam2' (/home/anjali/sam2/sam2/__init__.py)
#
# Skipping the post-processing step due to the error above. You can still use SAM 2 and it's OK to ignore the error above, although some post-processing functionality may be limited (which doesn't affect the results in most cases; see https://github.com/facebookresearch/sam2/blob/main/INSTALL.md).
#   pred_masks_gpu = fill_holes_in_mask_scores(
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.81it/s]
# propagate in video: 100%|██████████| 2/2 [00:03<00:00,  1.57s/it]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.67it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 64.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.81it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.25it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.68it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 44.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.45it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.37it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.19it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.95it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.98it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 65.70it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.94it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.68it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.07it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.81it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.38it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 66.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.16it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.45it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.95it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.45it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.79it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.60it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.73it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.80it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 22.47it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.78it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.60it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.21it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 22.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.76it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 23.85it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 21.12it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 22.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.84it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.91it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.93it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.67it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.57it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.84it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.21it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 65.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.66it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.21it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.20it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.16it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.82it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.24it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 64.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.80it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 65.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.20it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 67.31it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.60it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.38it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.36it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.78it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.49it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.97it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 39.45it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.05it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.20it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.03it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.40it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.12it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.71it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.16it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.79it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.17it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.66it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.92it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.47it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.94it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 40.30it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.38it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.94it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.05it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.73it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.68it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.49it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.82it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 43.81it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.79it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.82it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.66it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.82it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.84it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.34it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.84it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.20it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.82it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 40.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.49it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 18.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.34it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.16it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 17.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 20.37it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 19.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 43.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 16.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 44.43it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.93it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 15.82it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.85it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:03<00:00,  1.63s/it]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.68it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.38it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.94it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.38it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.19it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.24it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 64.72it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.72it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.69it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.33it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.29it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.40it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.14it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.53it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.05it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.37it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.34it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.36it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.50it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.17it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.69it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.36it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.97it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.56it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.91it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.82it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.93it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 68.36it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.98it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 64.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.68it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.21it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.68it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.47it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.66it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 64.21it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.05it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.09it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 61.49it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.89it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.78it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.03it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.47it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 66.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.12it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.72it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.71it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 65.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.56it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.75it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.31it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.87it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.43it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.56it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 62.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 63.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.95it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.21it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.05it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.53it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.16it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.08it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.49it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.18it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.92it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.14it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.85it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.40it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.91it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.45it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.75it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.85it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.79it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.30it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.34it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.14it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.72it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.47it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.98it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.19it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.50it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.75it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.45it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.50it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.73it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:03<00:00,  1.74s/it]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.36it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.80it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.72it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.43it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.36it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.84it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.43it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.40it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.68it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.47it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.08it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.89it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 41.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.79it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.53it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 43.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.34it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.95it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.72it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.96it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.87it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.17it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.47it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.81it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.67it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.47it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.68it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.70it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.30it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.69it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.84it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.36it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.08it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.82it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.85it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.92it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.65it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.81it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.12it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.21it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.60it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.66it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 44.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.25it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.67it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.57it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.53it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.57it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.89it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.53it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.21it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.40it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.67it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.65it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.69it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.40it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.67it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.29it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.33it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.45it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.65it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.92it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.31it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.59it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.53it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.79it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.53it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.36it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.92it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 43.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.19it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.66it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.30it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.72it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.79it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.76it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.21it/s]
# ...
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.92it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.65it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.08it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.34it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 60.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.40it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.49it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.80it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.33it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.72it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.03it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.50it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.59it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.81it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 42.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.43it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.85it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.47it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.72it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.19it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.67it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.57it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.56it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.40it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.36it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 38.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.47it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.84it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.21it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.31it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.98it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.31it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.25it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.40it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.60it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.79it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.57it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.29it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.79it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.53it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.21it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.71it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.71it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.36it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.43it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.49it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.34it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.08it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.98it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 58.53it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.41it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.76it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.69it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.40it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.40it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.76it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.95it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 45.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.72it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.38it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.92it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.19it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.57it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.05it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 57.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.60it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.71it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.94it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.43it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 59.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 53.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.87it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 52.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.73it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 51.59it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.03it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.66it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 56.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.33it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 55.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 14.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 54.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:03<00:00,  1.87s/it]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 42.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.58it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 46.25it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.56it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.66it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 44.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.94it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 12.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 48.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.96it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.29it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 47.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.32it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 49.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.72it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 50.75it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00, 13.57it/s]

# %% [markdown]
# > **Insight:** Average IoU per category is a strong indicator of how consistently the model or tracking method performs on different product classes, helping identify classes that may require additional data or tuning.

# %%
## Computing Average IoU per Category and per Category IoUs
avg_ious, per_item = average_iou_per_category_from_results(
    results,
    auto_resize=True,
    return_details=True
)

# Summary table for average IoU per category
summary_df = pd.DataFrame.from_dict(
    avg_ious, orient="index", columns=["Average IoU"]
).reset_index().rename(columns={"index": "Category"})

summary_df["Average IoU"] = summary_df["Average IoU"].round(3)

# Display average IoU per category
print("### Average IoU per Category")
display(summary_df)

# per-item IoUs for a specific category
category_name = "carton_oj"
if category_name in per_item:
    details_df = pd.DataFrame({
        "Image Index": range(1, len(per_item[category_name]) + 1),
        "IoU": [round(iou, 3) for iou in per_item[category_name]]
    })
    print(f"\n### Per-item IoUs for category: {category_name}")
    display(details_df)
# Out:
# ### Average IoU per Category
#           Category  Average IoU
# 0      can_chowder        0.218
# 1      can_soymilk        0.254
# 2   can_tomatosoup        0.150
# 3        carton_oj        0.401
# 4   carton_soymilk        0.373
# 5        diet_coke        0.370
# 6  hc_potroastsoup        0.297
# 7         juicebox        0.111
# 8      rice_tuscan        0.291
# 9        ricepilaf        0.035
# ### Per-item IoUs for category: carton_oj
#     Image Index    IoU
# 0             1  0.000
# 1             2  0.938
# 2             3  0.000
# 3             4  0.000
# 4             5  0.000
# 5             6  0.000
# 6             7  0.000
# 7             8  0.001
# 8             9  0.473
# 9            10  0.623
# 10           11  0.000
# 11           12  0.000
# 12           13  0.000
# 13           14  0.919
# 14           15  0.000
# 15           16  0.000
# 16           17  0.000
# 17           18  0.000
# 18           19  0.000
# 19           20  0.873
# 20           21  0.336
# 21           22  0.934
# 22           23  0.959
# 23           24  0.778
# 24           25  0.925
# 25           26  0.752
# 26           27  0.952
# 27           28  0.000
# 28           29  0.961
# 29           30  0.634
# 30           31  0.747
# 31           32  0.684
# 32           33  0.000
# 33           34  0.953
# 34           35  0.939
# 35           36  0.970
# 36           37  0.000
# 37           38  0.002
# 38           39  0.004
# 39           40  0.000
# 40           41  0.848
# 41           42  0.875
# 42           43  0.732
# 43           44  0.574
# 44           45  0.717
# 45           46  0.557
# 46           47  0.000
# 47           48  0.000
# 48           49  0.000
